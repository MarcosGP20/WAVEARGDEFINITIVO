-- %% [markdown]
-- # [WaveArg]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [WaveArg]    Script Date: 20/12/2025 16:49:07 ******/
CREATE DATABASE [WaveArg]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'WaveArg', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\WaveArg.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'WaveArg_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\WaveArg_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [WaveArg] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [WaveArg].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [WaveArg] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [WaveArg] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [WaveArg] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [WaveArg] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [WaveArg] SET ARITHABORT OFF 
GO
ALTER DATABASE [WaveArg] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [WaveArg] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [WaveArg] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [WaveArg] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [WaveArg] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [WaveArg] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [WaveArg] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [WaveArg] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [WaveArg] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [WaveArg] SET  ENABLE_BROKER 
GO
ALTER DATABASE [WaveArg] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [WaveArg] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [WaveArg] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [WaveArg] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [WaveArg] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [WaveArg] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [WaveArg] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [WaveArg] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [WaveArg] SET  MULTI_USER 
GO
ALTER DATABASE [WaveArg] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [WaveArg] SET DB_CHAINING OFF 
GO
ALTER DATABASE [WaveArg] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [WaveArg] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [WaveArg] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [WaveArg] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [WaveArg] SET QUERY_STORE = ON
GO
ALTER DATABASE [WaveArg] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Carrito]

-- %%
USE [WaveArg]
GO

-- %%
/****** Object:  Table [dbo].[Carrito]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Carrito](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[SesionId] [nvarchar](255) NULL,
	[UsuarioId] [int] NULL,
	[FechaCreacion] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CarritoItems]

-- %%
/****** Object:  Table [dbo].[CarritoItems]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CarritoItems](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CarritoId] [int] NULL,
	[ProductoId] [int] NULL,
	[Cantidad] [int] NULL,
	[ProductoVarianteId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Imagenes]

-- %%
/****** Object:  Table [dbo].[Imagenes]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Imagenes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductoId] [int] NULL,
	[Url] [nvarchar](255) NULL,
	[EsPrincipal] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PedidoItems]

-- %%
/****** Object:  Table [dbo].[PedidoItems]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PedidoItems](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PedidoId] [int] NULL,
	[ProductoId] [int] NULL,
	[Cantidad] [int] NULL,
	[PrecioUnitario] [decimal](10, 2) NULL,
	[ProductoVarianteId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pedidos]

-- %%
/****** Object:  Table [dbo].[Pedidos]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pedidos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[CarritoId] [int] NULL,
	[UsuarioId] [int] NULL,
	[Fecha] [datetime] NULL,
	[Total] [decimal](10, 2) NULL,
	[DireccionEnvio] [nvarchar](255) NULL,
	[Estado] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PresupuestoItems]

-- %%
/****** Object:  Table [dbo].[PresupuestoItems]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PresupuestoItems](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[PresupuestoId] [int] NULL,
	[ProductoId] [int] NULL,
	[Cantidad] [int] NULL,
	[PrecioUnitario] [decimal](10, 2) NULL,
	[ProductoVarianteId] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Presupuestos]

-- %%
/****** Object:  Table [dbo].[Presupuestos]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Presupuestos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Fecha] [datetime] NULL,
	[Email] [nvarchar](100) NULL,
	[Telefono] [nvarchar](50) NULL,
	[Comentarios] [nvarchar](max) NULL,
	[Enviado] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductoPrecios]

-- %%
/****** Object:  Table [dbo].[ProductoPrecios]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductoPrecios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductoId] [int] NULL,
	[TipoCliente] [nvarchar](50) NULL,
	[Precio] [decimal](10, 2) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
/****** Object:  Table [dbo].[Productos]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Productos](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NOT NULL,
	[Modelo] [nvarchar](100) NULL,
	[Descripcion] [nvarchar](max) NULL,
	[Activo] [bit] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProductoVariantes]

-- %%
/****** Object:  Table [dbo].[ProductoVariantes]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProductoVariantes](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductoId] [int] NOT NULL,
	[Color] [nvarchar](50) NOT NULL,
	[Memoria] [nvarchar](50) NOT NULL,
	[Precio] [decimal](18, 2) NOT NULL,
	[Stock] [int] NOT NULL,
	[EsUsado] [bit] NOT NULL,
	[DetalleEstado] [nvarchar](500) NULL,
	[FotoEstadoUrl] [nvarchar](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Roles]

-- %%
/****** Object:  Table [dbo].[Roles]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Roles](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Stock]

-- %%
/****** Object:  Table [dbo].[Stock]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Stock](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[ProductoId] [int] NULL,
	[Cantidad] [int] NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Usuarios]

-- %%
/****** Object:  Table [dbo].[Usuarios]    Script Date: 20/12/2025 16:49:07 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Usuarios](
	[Id] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [nvarchar](100) NULL,
	[Email] [nvarchar](100) NULL,
	[Contraseña] [nvarchar](255) NULL,
	[Rolid] [int] NULL,
	[FechaNacimiento] [date] NULL,
	[Provider] [nvarchar](100) NULL,
	[FechaRegistro] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[Id] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Imagenes]

-- %%
SET IDENTITY_INSERT [dbo].[Imagenes] ON 
INSERT [dbo].[Imagenes] ([Id], [ProductoId], [Url], [EsPrincipal]) VALUES (4, 2, N'https://store.storeimages.cdn-apple.com/4668/as-images.apple.com/is/iphone-14-starlight-select-202209?wid=5120&hei=2880&fmt=p-jpg', 0)
INSERT [dbo].[Imagenes] ([Id], [ProductoId], [Url], [EsPrincipal]) VALUES (5, 3, N'https://store.storeimages.cdn-apple.com/4668/as-images.apple.com/is/iphone-13-product-red-select-2021?wid=5120&hei=2880&fmt=p-jpg', 1)
INSERT [dbo].[Imagenes] ([Id], [ProductoId], [Url], [EsPrincipal]) VALUES (6, 2, N'https://store.storeimages.cdn-apple.com/4668/as-images.apple.com/is/iphone-1prueba-starlight-select-202209?wid=5120&hei=2880&fmt=p-jpg', 0)
SET IDENTITY_INSERT [dbo].[Imagenes] OFF
GO

-- %% [markdown]
-- # [dbo].[Productos]

-- %%
SET IDENTITY_INSERT [dbo].[Productos] ON 
INSERT [dbo].[Productos] ([Id], [Nombre], [Modelo], [Descripcion], [Activo]) VALUES (2, N'iPhone 14', N'A2882', N'Pantalla Super Retina XDR de 6.1 pulgadas. Sistema avanzado de cámaras para mejores fotos en cualquier luz. Modo Cine ahora en 4K Dolby Vision hasta 30 cps.', 1)
INSERT [dbo].[Productos] ([Id], [Nombre], [Modelo], [Descripcion], [Activo]) VALUES (3, N'iPhone 13 (Agotado)', N'A2633', N'Este producto es una prueba de stock cero. No debería verse en la tienda.', 1)
SET IDENTITY_INSERT [dbo].[Productos] OFF
GO

-- %% [markdown]
-- # [dbo].[ProductoVariantes]

-- %%
SET IDENTITY_INSERT [dbo].[ProductoVariantes] ON 
INSERT [dbo].[ProductoVariantes] ([Id], [ProductoId], [Color], [Memoria], [Precio], [Stock], [EsUsado], [DetalleEstado], [FotoEstadoUrl]) VALUES (3, 2, N'Medianoche', N'128GB', CAST(950.00 AS Decimal(18, 2)), 20, 0, NULL, NULL)
INSERT [dbo].[ProductoVariantes] ([Id], [ProductoId], [Color], [Memoria], [Precio], [Stock], [EsUsado], [DetalleEstado], [FotoEstadoUrl]) VALUES (4, 3, N'Product Red', N'128GB', CAST(800.00 AS Decimal(18, 2)), 0, 0, NULL, NULL)
SET IDENTITY_INSERT [dbo].[ProductoVariantes] OFF
GO

-- %% [markdown]
-- # [UQ__Usuarios__A9D10534581CD0EA]

-- %%
SET ANSI_PADDING ON
GO
/****** Object:  Index [UQ__Usuarios__A9D10534581CD0EA]    Script Date: 20/12/2025 16:49:07 ******/
ALTER TABLE [dbo].[Usuarios] ADD UNIQUE NONCLUSTERED 
(
	[Email] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, SORT_IN_TEMPDB = OFF, IGNORE_DUP_KEY = OFF, ONLINE = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Carrito__FechaCr__5FB337D6]

-- %%
ALTER TABLE [dbo].[Carrito] ADD  DEFAULT (getdate()) FOR [FechaCreacion]
GO

-- %% [markdown]
-- # [DF__Imagenes__EsPrin__60A75C0F]

-- %%
ALTER TABLE [dbo].[Imagenes] ADD  DEFAULT ((0)) FOR [EsPrincipal]
GO

-- %% [markdown]
-- # [DF__Pedidos__Fecha__619B8048]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF__Pedidos__Estado__628FA481]

-- %%
ALTER TABLE [dbo].[Pedidos] ADD  DEFAULT ('pendiente') FOR [Estado]
GO

-- %% [markdown]
-- # [DF__Presupues__Fecha__6383C8BA]

-- %%
ALTER TABLE [dbo].[Presupuestos] ADD  DEFAULT (getdate()) FOR [Fecha]
GO

-- %% [markdown]
-- # [DF__Presupues__Envia__6477ECF3]

-- %%
ALTER TABLE [dbo].[Presupuestos] ADD  DEFAULT ((0)) FOR [Enviado]
GO

-- %% [markdown]
-- # [DF__Productos__Activ__656C112C]

-- %%
ALTER TABLE [dbo].[Productos] ADD  DEFAULT ((1)) FOR [Activo]
GO

-- %% [markdown]
-- # [DF__ProductoV__Stock__0D7A0286]

-- %%
ALTER TABLE [dbo].[ProductoVariantes] ADD  DEFAULT ((0)) FOR [Stock]
GO

-- %% [markdown]
-- # [DF__ProductoV__EsUsa__0E6E26BF]

-- %%
ALTER TABLE [dbo].[ProductoVariantes] ADD  DEFAULT ((0)) FOR [EsUsado]
GO

-- %% [markdown]
-- # [DF__Usuarios__FechaR__66603565]

-- %%
ALTER TABLE [dbo].[Usuarios] ADD  DEFAULT (getdate()) FOR [FechaRegistro]
GO

-- %% [markdown]
-- # [FK__Carrito__Usuario__6754599E]

-- %%
ALTER TABLE [dbo].[Carrito]  WITH CHECK ADD FOREIGN KEY([UsuarioId])
REFERENCES [dbo].[Usuarios] ([Id])
GO

-- %% [markdown]
-- # [FK__CarritoIt__Carri__68487DD7]

-- %%
ALTER TABLE [dbo].[CarritoItems]  WITH CHECK ADD FOREIGN KEY([CarritoId])
REFERENCES [dbo].[Carrito] ([Id])
GO

-- %% [markdown]
-- # [FK__CarritoIt__Produ__693CA210]

-- %%
ALTER TABLE [dbo].[CarritoItems]  WITH CHECK ADD FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Productos] ([Id])
GO

-- %% [markdown]
-- # [FK_CarritoItems_Variantes]

-- %%
ALTER TABLE [dbo].[CarritoItems]  WITH CHECK ADD  CONSTRAINT [FK_CarritoItems_Variantes] FOREIGN KEY([ProductoVarianteId])
REFERENCES [dbo].[ProductoVariantes] ([Id])
GO
ALTER TABLE [dbo].[CarritoItems] CHECK CONSTRAINT [FK_CarritoItems_Variantes]
GO

-- %% [markdown]
-- # [FK__Imagenes__Produc__6A30C649]

-- %%
ALTER TABLE [dbo].[Imagenes]  WITH CHECK ADD FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Productos] ([Id])
GO

-- %% [markdown]
-- # [FK__PedidoIte__Pedid__6B24EA82]

-- %%
ALTER TABLE [dbo].[PedidoItems]  WITH CHECK ADD FOREIGN KEY([PedidoId])
REFERENCES [dbo].[Pedidos] ([Id])
GO

-- %% [markdown]
-- # [FK__PedidoIte__Produ__6C190EBB]

-- %%
ALTER TABLE [dbo].[PedidoItems]  WITH CHECK ADD FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Productos] ([Id])
GO

-- %% [markdown]
-- # [FK_PedidoItems_Variantes]

-- %%
ALTER TABLE [dbo].[PedidoItems]  WITH CHECK ADD  CONSTRAINT [FK_PedidoItems_Variantes] FOREIGN KEY([ProductoVarianteId])
REFERENCES [dbo].[ProductoVariantes] ([Id])
GO
ALTER TABLE [dbo].[PedidoItems] CHECK CONSTRAINT [FK_PedidoItems_Variantes]
GO

-- %% [markdown]
-- # [FK__Pedidos__Carrito__6D0D32F4]

-- %%
ALTER TABLE [dbo].[Pedidos]  WITH CHECK ADD FOREIGN KEY([CarritoId])
REFERENCES [dbo].[Carrito] ([Id])
GO

-- %% [markdown]
-- # [FK__Pedidos__Usuario__6E01572D]

-- %%
ALTER TABLE [dbo].[Pedidos]  WITH CHECK ADD FOREIGN KEY([UsuarioId])
REFERENCES [dbo].[Usuarios] ([Id])
GO

-- %% [markdown]
-- # [FK__Presupues__Presu__6EF57B66]

-- %%
ALTER TABLE [dbo].[PresupuestoItems]  WITH CHECK ADD FOREIGN KEY([PresupuestoId])
REFERENCES [dbo].[Presupuestos] ([Id])
GO

-- %% [markdown]
-- # [FK__Presupues__Produ__6FE99F9F]

-- %%
ALTER TABLE [dbo].[PresupuestoItems]  WITH CHECK ADD FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Productos] ([Id])
GO

-- %% [markdown]
-- # [FK_PresupuestoItems_Variantes]

-- %%
ALTER TABLE [dbo].[PresupuestoItems]  WITH CHECK ADD  CONSTRAINT [FK_PresupuestoItems_Variantes] FOREIGN KEY([ProductoVarianteId])
REFERENCES [dbo].[ProductoVariantes] ([Id])
GO
ALTER TABLE [dbo].[PresupuestoItems] CHECK CONSTRAINT [FK_PresupuestoItems_Variantes]
GO

-- %% [markdown]
-- # [FK__ProductoP__Produ__70DDC3D8]

-- %%
ALTER TABLE [dbo].[ProductoPrecios]  WITH CHECK ADD FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Productos] ([Id])
GO

-- %% [markdown]
-- # [FK_ProductoVariantes_Productos]

-- %%
ALTER TABLE [dbo].[ProductoVariantes]  WITH CHECK ADD  CONSTRAINT [FK_ProductoVariantes_Productos] FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Productos] ([Id])
GO
ALTER TABLE [dbo].[ProductoVariantes] CHECK CONSTRAINT [FK_ProductoVariantes_Productos]
GO

-- %% [markdown]
-- # [FK__Stock__ProductoI__71D1E811]

-- %%
ALTER TABLE [dbo].[Stock]  WITH CHECK ADD FOREIGN KEY([ProductoId])
REFERENCES [dbo].[Productos] ([Id])
GO

-- %% [markdown]
-- # [FK_Usuarios_Roles]

-- %%
ALTER TABLE [dbo].[Usuarios]  WITH CHECK ADD  CONSTRAINT [FK_Usuarios_Roles] FOREIGN KEY([Rolid])
REFERENCES [dbo].[Roles] ([Id])
GO
ALTER TABLE [dbo].[Usuarios] CHECK CONSTRAINT [FK_Usuarios_Roles]
GO

-- %% [markdown]
-- # [CK__Pedidos__Estado__73BA3083]

-- %%
ALTER TABLE [dbo].[Pedidos]  WITH CHECK ADD CHECK  (([Estado]='cancelado' OR [Estado]='enviado' OR [Estado]='procesando' OR [Estado]='pendiente'))
GO

-- %% [markdown]
-- # [CK__ProductoP__TipoC__74AE54BC]

-- %%
ALTER TABLE [dbo].[ProductoPrecios]  WITH CHECK ADD CHECK  (([TipoCliente]='mayorista' OR [TipoCliente]='minorista'))
GO

-- %% [markdown]
-- # [WaveArg]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [WaveArg] SET  READ_WRITE 
GO
